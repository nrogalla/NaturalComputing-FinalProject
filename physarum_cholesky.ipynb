# %%
# !pip install tsplib95
import numpy as np
import gzip
import shutil
import matplotlib.pyplot as plt
import time
import networkx as nx
import tsplib95
import tracemalloc
from scipy.sparse.linalg import cg
from scipy.sparse import csr_matrix
from scipy.linalg import cholesky

# Function to extract .gz file
def extract_gzip(source_filepath, destination_filepath):
    with gzip.open(source_filepath, 'rb') as f_in, open(destination_filepath, 'wb') as f_out:
        shutil.copyfileobj(f_in, f_out)

# Function to load coordinates from the .tsp file
def load_coordinates(file_path):
    coordinates = []
    start_reading = False
    with open(file_path, 'r') as file:
        for line in file:
            if "NODE_COORD_SECTION" in line:
                start_reading = True
            elif "EOF" in line:
                break
            elif start_reading:
                parts = line.strip().split()
                if len(parts) == 3 and parts[0].isdigit():
                    coordinates.append((float(parts[1]), float(parts[2])))
    return coordinates

# Function to calculate fluxes
def calculate_fluxes(pressures, conductivities, distances, epsilon=1e-10):
    num_cities = len(pressures)
    fluxes = np.zeros((num_cities, num_cities))
    for i in range(num_cities):
        for j in range(num_cities):
            if i != j:
                distance = max(distances[i][j], epsilon)  # Avoid division by zero
                delta_p = np.clip(pressures[i] - pressures[j], -1e3, 1e3)  # Ensure pressures do not cause overflow
                fluxes[i][j] = (conductivities[i][j] / distance) * delta_p
    return fluxes

# Type I function (power function) for flux-conductance relationship
def type_i_function(flux, k, m):
    return k * (flux ** m)

# Type II function (sigmoidal profile) for flux-conductance relationship
def type_ii_function(flux, k, midpoint, steepness):
    return k / (1 + np.exp(-steepness * (flux - midpoint)))

# Function to solve the Poisson equation using ICCG method
def solve_poisson_iccg(pressures, fluxes, conductivities, distances, epsilon=1e-10):
    num_cities = len(pressures)
    A = np.zeros((num_cities, num_cities))
    b = np.zeros(num_cities)

    for i in range(num_cities):
        for j in range(num_cities):
            if i != j:
                A[i, i] += conductivities[i, j] / max(distances[i, j], epsilon)
                A[i, j] -= conductivities[i, j] / max(distances[i, j], epsilon)
        b[i] = np.sum(fluxes[:, i]) - np.sum(fluxes[i, :])

    A_sparse = csr_matrix(A)
    L = cholesky(A_sparse.todense() + np.eye(num_cities) * epsilon, lower=True)
    pressures, _ = cg(A_sparse, b, x0=pressures, M=L)
    return pressures

# Function to update conductivities with a semi-implicit scheme
def update_conductivities(conductivities, fluxes, decay_rate, k, m, noise_factor, func_type='type_i', midpoint=None, steepness=None):
    num_cities = len(conductivities)
    for i in range(num_cities):
        for j in range(num_cities):
            if i != j:
                flux = np.clip(abs(fluxes[i][j]), 0, 1e3)  # Control the size of the flux to prevent overflow
                if func_type == 'type_i':
                    growth = type_i_function(flux, k, m)
                elif func_type == 'type_ii':
                    if midpoint is None or steepness is None:
                        raise ValueError("midpoint and steepness must be provided for type_ii function")
                    growth = type_ii_function(flux, k, midpoint, steepness)
                else:
                    raise ValueError("Invalid function type. Use 'type_i' or 'type_ii'.")

                # Semi-implicit update
                conductivities[i][j] = (conductivities[i][j] + growth * noise_factor) / (1 + decay_rate)
                conductivities[i][j] = np.clip(conductivities[i][j], -1e3, 1e3)  # Limit the conductivities to prevent overflow
    return conductivities

# Function to update pressures
def update_pressures(pressures, fluxes, rate=0.05):
    num_cities = len(pressures)
    for i in range(num_cities):
        net_influx = np.sum(fluxes[:, i]) - np.sum(fluxes[i, :])
        pressures[i] += rate * net_influx
        pressures[i] = np.clip(pressures[i], 0, 1e2)  # Prevent pressure from becoming negative or excessively high
    return pressures

# Function to prune connections
def prune_connections(conductivities, threshold=0.005):
    conductivities[conductivities < threshold] = 0
    return conductivities

# Function to construct TSP path
def construct_tsp_path(conductivities, fluxes):
    num_cities = len(conductivities)
    visited = np.zeros(num_cities, dtype=bool)
    path = []

    start_city = np.random.randint(0, num_cities)  # Random starting city
    path.append(start_city)
    visited[start_city] = True

    current_city = start_city

    while len(path) < num_cities:
        next_city = -1
        max_value = 0

        for j in range(num_cities):
            if not visited[j]:
                value = conductivities[current_city][j] * np.abs(fluxes[current_city][j])
                if value > max_value:
                    next_city = j
                    max_value = value

        if next_city == -1:
            return None  # If no valid next city is found, return None

        path.append(next_city)
        visited[next_city] = True
        current_city = next_city

    if len(path) == num_cities:
        return path

    return None

# Function to calculate the total distance of a given path
def calculate_total_distance(path, distances):
    total_distance = 0
    for i in range(len(path) - 1):
        if distances[path[i], path[i + 1]] == np.inf:
            print(f"Invalid distance between {path[i]} and {path[i + 1]}")
            return np.inf
        total_distance += distances[path[i], path[i + 1]]

    total_distance += distances[path[-1], path[0]]
    return total_distance

# Function to calculate memory usage
def calculate_memory_usage(conductivities):
    return conductivities.nbytes

# Function to plot the best path
def plot_best_path(best_path, cities, ax=None):
    path_coords = cities[best_path]

    if ax is None:
        ax = plt.gca()
    else:
        ax.clear()

    ax.plot(path_coords[:, 0], path_coords[:, 1], 'o-', markersize=10)
    ax.plot([path_coords[-1, 0], path_coords[0, 0]], [path_coords[-1, 1], path_coords[0, 1]], 'o-', markersize=10)  # Connect last to first

    for i, coord in enumerate(path_coords):
        ax.annotate(str(best_path[i]), (coord[0], coord[1]))  # Use index from best_path for annotation

    ax.set_title("Best Path")
    ax.set_xlabel("X Coordinate")
    ax.set_ylabel("Y Coordinate")
    ax.grid(True)

# Function to plot the fitness over iterations
def plot_fitness_over_iterations(all_fitness, ax=None):
    if ax is None:
        ax = plt.gca()
    ax.clear()
    ax.plot(all_fitness, 'o-', markersize=5)
    ax.set_title("Fitness over Iterations")
    ax.set_xlabel("Iteration")
    ax.set_ylabel("Total Distance (Fitness)")
    ax.grid(True)

# Simulation loop function
def run_simulation(dataset_name, noise_factor, func_type='type_i', midpoint=None, steepness=None):
    # Extract and load city coordinates
    source_filepath = f'{dataset_name}.tsp.gz'
    destination_filepath = f'{dataset_name}.tsp'
    extract_gzip(source_filepath, destination_filepath)
    cities = np.array(load_coordinates(destination_filepath))
    print(f"Loaded coordinates for {len(cities)} cities from {dataset_name}.")

    with open(destination_filepath) as f:
        text = f.read()

    problem = tsplib95.parse(text)
    graph = problem.get_graph()
    distances = nx.to_numpy_array(graph, dtype=float)

    # Replace zero distances with a very small value to avoid division by zero
    distances[distances == 0] = np.inf

    # Initialize pressures and conductivities
    pressures = np.random.rand(len(cities)) * 10
    conductivities = np.ones_like(distances) * 0.01  # Initial small value for all conductivities

    decay_rate = 0.01
    k = 0.1
    m = 2
    epsilon = 1e-10

    num_iterations = 100
    best_fitness = np.inf
    best_path = None
    best_distances = []
    computation_times = []
    convergence_rates = []
    memory_usages = []
    all_solutions = []
    all_paths = []

    start_time = time.time()
    tracemalloc.start()
    snapshot1 = tracemalloc.take_snapshot()
    for iteration in range(num_iterations):
        iteration_start_time = time.time()

        fluxes = calculate_fluxes(pressures, conductivities, distances)

        # Update pressures using ICCG
        pressures = solve_poisson_iccg(pressures, fluxes, conductivities, distances, epsilon)

        # Semi-implicit update of conductivities
        conductivities = update_conductivities(conductivities, fluxes, decay_rate, k, m, noise_factor, func_type, midpoint, steepness)

        conductivities = prune_connections(conductivities)
        current_path = construct_tsp_path(conductivities, fluxes)
        if current_path is None:
            continue

        current_fitness = calculate_total_distance(current_path, distances)
        all_paths.append(current_path)
        all_solutions.append(current_fitness)

        if current_fitness < best_fitness:
            best_fitness = current_fitness
            best_path = current_path

        best_distances.append(best_fitness)
        convergence_rates.append(best_fitness)

        iteration_end_time = time.time()
        computation_times.append(iteration_end_time - iteration_start_time)

        memory_usages.append(calculate_memory_usage(conductivities))

        # Print the length of the tour for the current best path
        if best_path is not None:
            tour_length = calculate_total_distance(best_path, distances)
            # print(f"Iteration {iteration}, Best Path Length: {tour_length}")

    total_computation_time = time.time() - start_time
    snapshot2 = tracemalloc.take_snapshot()
    tracemalloc.stop()

    stats_initial = snapshot2.compare_to(snapshot1, 'lineno')
    total_memory_allocated_initial = sum(stat.size_diff for stat in stats_initial)

    print(f"Best Fitness for {dataset_name} with noise factor {noise_factor}:", best_fitness)
    print("Best Path:", best_path)
    print("Total Computation Time:", total_computation_time, "seconds")
    print("Average Computation Time per Iteration:", np.mean(computation_times), "seconds")
    print("Memory Usage:", memory_usages[-1], "bytes")
    print("Memory Usage: ", total_memory_allocated_initial/(1024**2), 'megabytes')

    # Plot the best path
    plt.figure()
    plot_best_path(best_path, cities)
    plt.title(f"Best Path for {dataset_name} (Noise factor {noise_factor})")
    plt.show()


#Run simulation for each dataset and noise factor
datasets = ['ulysses22', 'st70', 'ch150']
noise_factors = [0.1, 10, 30, 50]


for dataset in datasets:
    for noise_factor in noise_factors:
        run_simulation(dataset, noise_factor, func_type='type_i')  # For Type I function
        run_simulation(dataset, noise_factor, func_type='type_ii', midpoint=0.5, steepness=5)  # For Type II function
# Out:
# Requirement already satisfied: tsplib95 in /usr/local/lib/python3.10/dist-packages (0.7.1)
# Requirement already satisfied: Click>=6.0 in /usr/local/lib/python3.10/dist-packages (from tsplib95) (8.1.7)
# Requirement already satisfied: Deprecated~=1.2.9 in /usr/local/lib/python3.10/dist-packages (from tsplib95) (1.2.14)
# Requirement already satisfied: networkx~=2.1 in /usr/local/lib/python3.10/dist-packages (from tsplib95) (2.8.8)
# Requirement already satisfied: tabulate~=0.8.7 in /usr/local/lib/python3.10/dist-packages (from tsplib95) (0.8.10)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from Deprecated~=1.2.9->tsplib95) (1.14.1)
# Loaded coordinates for 22 cities from ulysses22.
# Best Fitness for ulysses22 with noise factor 0.1: 7789.0
# Best Path: [3, 17, 21, 16, 0, 7, 15, 11, 12, 13, 6, 5, 18, 19, 20, 9, 8, 10, 4, 14, 1, 2]
# Total Computation Time: 5.004378318786621 seconds
# Average Computation Time per Iteration: 0.05098653876263162 seconds
# Memory Usage: 3872 bytes
# Memory Usage:  0.07496070861816406 megabytes
# Loaded coordinates for 22 cities from ulysses22.
# Best Fitness for ulysses22 with noise factor 0.1: 7678.0
# Best Path: [3, 17, 21, 16, 1, 2, 15, 0, 7, 12, 13, 6, 5, 14, 11, 19, 20, 18, 9, 8, 10, 4]
# Total Computation Time: 7.288684129714966 seconds
# Average Computation Time per Iteration: 0.07281727313995362 seconds
# Memory Usage: 3872 bytes
# Memory Usage:  0.1088876724243164 megabytes
# Loaded coordinates for 22 cities from ulysses22.
# Best Fitness for ulysses22 with noise factor 10: 8202.0
# Best Path: [8, 18, 19, 20, 9, 12, 13, 11, 6, 5, 14, 7, 0, 15, 21, 17, 3, 16, 2, 1, 4, 10]
# Total Computation Time: 5.7005815505981445 seconds
# Average Computation Time per Iteration: 0.056085548539092575 seconds
# Memory Usage: 3872 bytes
# Memory Usage:  0.06513500213623047 megabytes
# Loaded coordinates for 22 cities from ulysses22.
# Best Fitness for ulysses22 with noise factor 10: 7794.0
# Best Path: [0, 7, 21, 16, 3, 17, 1, 2, 15, 11, 12, 13, 14, 6, 5, 18, 19, 20, 9, 8, 10, 4]
# Total Computation Time: 6.943533420562744 seconds
# Average Computation Time per Iteration: 0.06935316801071167 seconds
# Memory Usage: 3872 bytes
# Memory Usage:  0.13796424865722656 megabytes
# Loaded coordinates for 22 cities from ulysses22.
# Best Fitness for ulysses22 with noise factor 30: 8026.0
# Best Path: [8, 19, 20, 18, 9, 12, 13, 11, 15, 0, 7, 21, 16, 3, 17, 1, 2, 14, 5, 6, 4, 10]
# Total Computation Time: 5.881333589553833 seconds
# Average Computation Time per Iteration: 0.05617390853771265 seconds
# Memory Usage: 3872 bytes
# Memory Usage:  0.0822601318359375 megabytes
# Loaded coordinates for 22 cities from ulysses22.
# Best Fitness for ulysses22 with noise factor 30: 7920.0
# Best Path: [8, 9, 18, 19, 20, 11, 12, 13, 14, 5, 6, 15, 0, 7, 21, 16, 3, 17, 1, 2, 4, 10]
# Total Computation Time: 6.768476486206055 seconds
# Average Computation Time per Iteration: 0.06761773586273194 seconds
# Memory Usage: 3872 bytes
# Memory Usage:  0.09430313110351562 megabytes
# Loaded coordinates for 22 cities from ulysses22.
# Best Fitness for ulysses22 with noise factor 50: 7860.0
# Best Path: [4, 14, 13, 12, 11, 6, 5, 19, 20, 18, 9, 15, 0, 7, 21, 16, 3, 17, 1, 2, 8, 10]
# Total Computation Time: 6.186417818069458 seconds
# Average Computation Time per Iteration: 0.0572356000731263 seconds
# Memory Usage: 3872 bytes
# Memory Usage:  0.0931692123413086 megabytes
# Loaded coordinates for 22 cities from ulysses22.
# Best Fitness for ulysses22 with noise factor 50: 7556.0
# Best Path: [2, 1, 16, 21, 3, 17, 7, 0, 15, 12, 13, 11, 20, 19, 9, 18, 6, 5, 14, 4, 10, 8]
# Total Computation Time: 6.50027322769165 seconds
# Average Computation Time per Iteration: 0.06493665218353271 seconds
# Memory Usage: 3872 bytes
# Memory Usage:  0.10304546356201172 megabytes
# Loaded coordinates for 70 cities from st70.
# Best Fitness for st70 with noise factor 0.1: 819.0
# Best Path: [5, 40, 16, 42, 67, 43, 29, 19, 13, 27, 7, 25, 48, 54, 18, 6, 1, 3, 17, 41, 2, 31, 23, 14, 56, 21, 62, 58, 37, 68, 12, 28, 69, 30, 34, 65, 52, 4, 9, 51, 59, 11, 33, 20, 32, 53, 61, 47, 66, 55, 64, 50, 49, 57, 36, 15, 46, 22, 0, 35, 63, 10, 38, 44, 24, 60, 39, 26, 45, 8]
# Total Computation Time: 55.17718958854675 seconds
# Average Computation Time per Iteration: 0.5515666246414185 seconds
# Memory Usage: 39200 bytes
# Memory Usage:  0.18050193786621094 megabytes
# Loaded coordinates for 70 cities from st70.
# Best Fitness for st70 with noise factor 0.1: 773.0
# Best Path: [67, 43, 29, 13, 19, 27, 7, 25, 48, 54, 18, 6, 1, 3, 17, 41, 40, 5, 42, 16, 20, 33, 11, 59, 32, 53, 61, 66, 47, 10, 55, 50, 64, 63, 36, 57, 49, 9, 51, 4, 52, 65, 62, 21, 37, 58, 68, 30, 69, 28, 12, 22, 46, 15, 35, 0, 34, 56, 14, 23, 31, 2, 8, 39, 60, 44, 38, 24, 45, 26]
# Total Computation Time: 56.97304725646973 seconds
# Average Computation Time per Iteration: 0.5695343613624573 seconds
# Memory Usage: 39200 bytes
# Memory Usage:  0.19694805145263672 megabytes
# Loaded coordinates for 70 cities from st70.
# Best Fitness for st70 with noise factor 10: 810.0
# Best Path: [29, 19, 13, 27, 7, 25, 48, 54, 18, 6, 1, 17, 3, 5, 40, 42, 16, 33, 20, 11, 59, 51, 9, 4, 52, 65, 21, 62, 58, 37, 68, 30, 12, 28, 69, 34, 22, 0, 15, 46, 36, 57, 49, 50, 64, 55, 66, 47, 53, 61, 32, 10, 63, 35, 14, 23, 56, 41, 31, 2, 43, 67, 8, 39, 60, 38, 44, 24, 45, 26]
# Total Computation Time: 51.53797125816345 seconds
# Average Computation Time per Iteration: 0.5151881742477417 seconds
# Memory Usage: 39200 bytes
# Memory Usage:  0.39397430419921875 megabytes
# Loaded coordinates for 70 cities from st70.
# Best Fitness for st70 with noise factor 10: 787.0
# Best Path: [10, 47, 66, 53, 32, 59, 11, 20, 33, 16, 42, 40, 5, 41, 17, 3, 1, 18, 6, 2, 31, 7, 27, 25, 48, 54, 13, 19, 29, 43, 67, 26, 45, 39, 60, 38, 44, 24, 8, 61, 55, 64, 50, 49, 57, 36, 15, 46, 22, 35, 0, 12, 28, 69, 30, 68, 34, 58, 62, 65, 21, 37, 56, 23, 14, 52, 4, 9, 51, 63]
# Total Computation Time: 51.953636169433594 seconds
# Average Computation Time per Iteration: 0.5193368339538574 seconds
# Memory Usage: 39200 bytes
# Memory Usage:  0.1678476333618164 megabytes
# Loaded coordinates for 70 cities from st70.
# Best Fitness for st70 with noise factor 30: 811.0
# Best Path: [26, 45, 39, 60, 38, 44, 24, 8, 67, 43, 29, 19, 13, 27, 7, 25, 48, 54, 6, 1, 3, 17, 41, 5, 40, 31, 2, 18, 23, 14, 56, 21, 62, 65, 37, 58, 68, 30, 12, 28, 69, 34, 0, 35, 22, 46, 15, 36, 57, 49, 9, 4, 52, 51, 59, 11, 33, 20, 53, 32, 66, 47, 10, 55, 64, 50, 63, 61, 16, 42]
# Total Computation Time: 51.643922090530396 seconds
# Average Computation Time per Iteration: 0.5162444019317627 seconds
# Memory Usage: 39200 bytes
# Memory Usage:  0.16724300384521484 megabytes
# Loaded coordinates for 70 cities from st70.
# Best Fitness for st70 with noise factor 30: 776.0
# Best Path: [52, 4, 51, 9, 49, 36, 57, 46, 15, 35, 0, 22, 28, 12, 30, 68, 69, 34, 37, 58, 62, 21, 65, 56, 14, 23, 1, 3, 17, 41, 5, 40, 16, 42, 67, 43, 29, 19, 13, 27, 7, 25, 48, 54, 18, 6, 2, 31, 8, 39, 60, 38, 44, 24, 45, 26, 20, 33, 11, 59, 32, 53, 61, 47, 66, 55, 64, 50, 10, 63]
# Total Computation Time: 51.89292860031128 seconds
# Average Computation Time per Iteration: 0.5187396121025085 seconds
# Memory Usage: 39200 bytes
# Memory Usage:  0.16097354888916016 megabytes
# Loaded coordinates for 70 cities from st70.
# Best Fitness for st70 with noise factor 50: 827.0
# Best Path: [36, 57, 49, 9, 4, 52, 5, 40, 42, 16, 33, 20, 11, 59, 32, 53, 61, 66, 47, 10, 55, 50, 64, 63, 51, 15, 46, 22, 0, 35, 12, 28, 30, 68, 69, 34, 37, 58, 21, 62, 65, 56, 14, 23, 1, 6, 31, 7, 27, 25, 48, 54, 18, 17, 3, 41, 2, 13, 19, 29, 43, 67, 8, 60, 39, 44, 38, 24, 45, 26]
# Total Computation Time: 49.544034004211426 seconds
# Average Computation Time per Iteration: 0.4952507495880127 seconds
# Memory Usage: 39200 bytes
# Memory Usage:  0.16074466705322266 megabytes
# Loaded coordinates for 70 cities from st70.
# Best Fitness for st70 with noise factor 50: 802.0
# Best Path: [51, 9, 4, 49, 36, 57, 46, 15, 0, 35, 22, 37, 21, 62, 58, 68, 30, 12, 28, 69, 34, 56, 14, 23, 1, 6, 31, 2, 7, 27, 25, 48, 54, 13, 29, 19, 43, 67, 42, 16, 20, 33, 11, 59, 32, 53, 66, 47, 10, 55, 64, 50, 63, 61, 38, 44, 24, 60, 39, 26, 45, 8, 40, 5, 41, 17, 3, 18, 65, 52]
# Total Computation Time: 52.033303022384644 seconds
# Average Computation Time per Iteration: 0.5201460099220276 seconds
# Memory Usage: 39200 bytes
# Memory Usage:  0.15632152557373047 megabytes
# Loaded coordinates for 150 cities from ch150.
# Best Fitness for ch150 with noise factor 0.1: 9090.0
# Best Path: [91, 53, 137, 45, 89, 82, 55, 25, 145, 123, 92, 125, 51, 110, 104, 132, 15, 58, 78, 120, 93, 87, 9, 47, 62, 29, 88, 7, 83, 6, 102, 97, 0, 86, 33, 75, 72, 112, 2, 61, 148, 124, 21, 103, 3, 44, 70, 43, 114, 149, 20, 14, 77, 79, 13, 121, 76, 130, 37, 22, 31, 66, 42, 108, 50, 19, 24, 109, 80, 28, 85, 134, 69, 107, 18, 1, 36, 41, 8, 27, 5, 98, 113, 101, 49, 54, 57, 140, 64, 84, 141, 17, 74, 96, 99, 142, 106, 94, 81, 4, 95, 34, 32, 133, 11, 23, 117, 52, 39, 138, 119, 46, 115, 100, 38, 56, 40, 116, 59, 65, 16, 147, 10, 60, 35, 68, 126, 129, 128, 26, 30, 122, 73, 135, 111, 63, 71, 146, 48, 143, 144, 12, 105, 90, 118, 67, 127, 139, 131, 136]
# Total Computation Time: 224.48264956474304 seconds
# Average Computation Time per Iteration: 2.278848191670009 seconds
# Memory Usage: 180000 bytes
# Memory Usage:  0.3137168884277344 megabytes
# Loaded coordinates for 150 cities from ch150.
# Best Fitness for ch150 with noise factor 0.1: 8510.0
# Best Path: [8, 36, 27, 41, 119, 138, 39, 23, 117, 126, 68, 60, 35, 10, 147, 129, 59, 65, 16, 139, 116, 56, 38, 40, 100, 115, 11, 42, 108, 50, 19, 24, 89, 137, 45, 53, 91, 32, 125, 34, 92, 123, 88, 7, 6, 83, 29, 62, 47, 72, 75, 86, 0, 97, 102, 33, 95, 9, 112, 93, 120, 78, 58, 14, 77, 15, 132, 76, 121, 13, 79, 71, 48, 146, 143, 128, 30, 26, 144, 111, 135, 63, 43, 70, 44, 127, 67, 118, 90, 105, 12, 73, 122, 37, 22, 31, 130, 133, 66, 52, 109, 46, 80, 28, 85, 107, 69, 134, 49, 57, 54, 64, 74, 25, 55, 82, 140, 1, 18, 98, 113, 101, 136, 131, 84, 141, 17, 99, 142, 4, 106, 94, 81, 96, 145, 110, 104, 20, 149, 114, 3, 103, 21, 148, 124, 61, 2, 87, 51, 5]
# Total Computation Time: 240.12053227424622 seconds
# Average Computation Time per Iteration: 2.40081657409668 seconds
# Memory Usage: 180000 bytes
# Memory Usage:  0.40242862701416016 megabytes
# Loaded coordinates for 150 cities from ch150.
# Best Fitness for ch150 with noise factor 10: 9696.0
# Best Path: [115, 100, 40, 56, 38, 126, 68, 35, 60, 10, 147, 65, 16, 59, 129, 116, 139, 26, 128, 143, 48, 146, 71, 13, 79, 121, 76, 15, 58, 77, 14, 110, 104, 32, 125, 92, 34, 88, 95, 7, 83, 29, 6, 97, 0, 86, 72, 47, 62, 112, 9, 93, 87, 78, 120, 132, 51, 123, 145, 25, 55, 82, 140, 57, 54, 49, 134, 69, 107, 85, 28, 80, 109, 1, 36, 41, 8, 27, 5, 98, 18, 113, 101, 136, 131, 64, 84, 141, 17, 96, 99, 142, 106, 94, 81, 4, 102, 75, 33, 2, 61, 148, 124, 149, 114, 43, 70, 127, 44, 3, 103, 118, 67, 12, 105, 63, 135, 111, 144, 73, 122, 30, 22, 37, 31, 130, 42, 66, 108, 50, 19, 89, 53, 91, 24, 45, 137, 133, 46, 119, 138, 39, 52, 23, 117, 11, 74, 20, 21, 90]
# Total Computation Time: 219.58686089515686 seconds
# Average Computation Time per Iteration: 2.200599363871983 seconds
# Memory Usage: 180000 bytes
# Memory Usage:  0.3795661926269531 megabytes
# Loaded coordinates for 150 cities from ch150.
# Best Fitness for ch150 with noise factor 10: 8884.0
# Best Path: [32, 104, 110, 132, 15, 58, 78, 120, 87, 93, 9, 112, 2, 61, 148, 124, 21, 103, 3, 149, 114, 43, 70, 127, 44, 67, 118, 90, 105, 12, 73, 135, 111, 63, 13, 79, 121, 77, 14, 20, 76, 130, 22, 37, 31, 66, 42, 108, 50, 19, 24, 109, 28, 85, 134, 69, 107, 101, 113, 98, 18, 1, 36, 8, 27, 41, 46, 119, 138, 52, 23, 117, 126, 68, 35, 60, 10, 147, 129, 59, 16, 65, 139, 56, 38, 100, 115, 11, 39, 40, 116, 26, 30, 144, 48, 146, 143, 71, 128, 122, 137, 133, 45, 53, 89, 91, 125, 92, 34, 95, 88, 7, 6, 83, 29, 62, 47, 72, 75, 33, 97, 0, 102, 86, 94, 106, 81, 4, 99, 142, 96, 25, 145, 55, 82, 74, 141, 17, 84, 131, 64, 54, 57, 80, 140, 136, 49, 5, 51, 123]
# Total Computation Time: 231.59615755081177 seconds
# Average Computation Time per Iteration: 2.3155708074569703 seconds
# Memory Usage: 180000 bytes
# Memory Usage:  0.37921810150146484 megabytes
# Loaded coordinates for 150 cities from ch150.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-0f7f659b660f> in <cell line: 294>()
#     294 for dataset in datasets:
#     295     for noise_factor in noise_factors:
# --> 296         run_simulation(dataset, noise_factor, func_type='type_i')  # For Type I function
#     297         run_simulation(dataset, noise_factor, func_type='type_ii', midpoint=0.5, steepness=5)  # For Type II function
#
# <ipython-input-6-0f7f659b660f> in run_simulation(dataset_name, noise_factor, func_type, midpoint, steepness)
#     235
#     236         # Update pressures using ICCG
# --> 237         pressures = solve_poisson_iccg(pressures, fluxes, conductivities, distances, epsilon)
#     238
#     239         # Semi-implicit update of conductivities
#
# <ipython-input-6-0f7f659b660f> in solve_poisson_iccg(pressures, fluxes, conductivities, distances, epsilon)
#      67
#      68     A_sparse = csr_matrix(A)
# ---> 69     L = cholesky(A_sparse.todense() + np.eye(num_cities) * epsilon, lower=True)
#      70     pressures, _ = cg(A_sparse, b, x0=pressures, M=L)
#      71     return pressures
#
# /usr/local/lib/python3.10/dist-packages/scipy/linalg/_decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      87
#      88     """
# ---> 89     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
#      90                          check_finite=check_finite)
#      91     return c
#
# /usr/local/lib/python3.10/dist-packages/scipy/linalg/_decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      15     """Common code for cholesky() and cho_factor()."""
#      16
# ---> 17     a1 = asarray_chkfinite(a) if check_finite else asarray(a)
#      18     a1 = atleast_2d(a1)
#      19
#
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py in asarray_chkfinite(a, dtype, order)
#     628     a = asarray(a, dtype=dtype, order=order)
#     629     if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
# --> 630         raise ValueError(
#     631             "array must not contain infs or NaNs")
#     632     return a
#
# ValueError: array must not contain infs or NaNs
